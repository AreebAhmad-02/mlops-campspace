# %%
# !pip install pyarrow -q

# !pip install --upgrade scikit-learn -q

# %%
print("my name is areeb")

df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet')
# Out:
# my name is areeb

# %%
import pandas as pd

import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error
import pickle

# %%
import pickle

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

# %%
std_duration = df['duration'].std()
std_duration
# Out:
# 42.594351241920904

# %%
# Get the total number of records in the original DataFrame
total_records = len(df)

# Apply the filter to create the new DataFrame
filtered_df = df[(df.duration >= 1) & (df.duration <= 60)]

# Get the number of records in the filtered DataFrame
filtered_records = len(filtered_df)

# Calculate the fraction
fraction = filtered_records / total_records

# Print the result
print(f"The fraction of records with duration between 1 and 60 minutes is: {fraction:.4f}")

# Now you can reassign df to the filtered DataFrame if you want to proceed with the filtered data
df = filtered_df
# Out:
# The fraction of records with duration between 1 and 60 minutes is: 0.9812

# %%
# df = pd.read_parquet('./data/green_tripdata_2021-01.parquet')


df = df[(df.duration >= 1) & (df.duration <= 60)]
time_comb = ['tpep_pickup_datetime','tpep_dropoff_datetime']
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)
# df[time_comb] = df[time_comb].astype(str)

# %%
# .to_dict(orient='records') is a convenient way to do this
df_dicts = df[categorical].to_dict(orient='records')

# Instantiate the DictVectorizer
dv = DictVectorizer()

# Fit and transform the data
# fit_transform performs both fitting and transforming in one step
X = dv.fit_transform(df_dicts)

# Get the dimensionality of the matrix (number of columns)
dimensionality = X.shape[1]

# %%
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6018346 stored elements and shape (3009173, 515)>

# %%
print(dimensionality)
# Out:
# 515

# %%
X_train = X

# %%
target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

root_mean_squared_error(y_train, y_pred)
# Out:
# 7.649261932106969

# %%
df[categorical]
# Out:
#         PULocationID DOLocationID
# 0                161          141
# 1                 43          237
# 2                 48          238
# 3                138            7
# 4                107           79
# ...              ...          ...
# 3066761          107           48
# 3066762          112           75
# 3066763          114          239
# 3066764          230           79
# 3066765          262          143
#
# [3009173 rows x 2 columns]

# %%
with open('lin_reg_2023_01.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
print("my name is areeb")

df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet')
# Out:
# my name is areeb

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
# 1               2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 2               2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 3               1  2023-02-01 00:29:33   2023-02-01 01:01:38              0.0
# 4               2  2023-02-01 00:12:28   2023-02-01 00:25:46              1.0
# ...           ...                  ...                   ...              ...
# 2913950         2  2023-02-28 23:46:00   2023-03-01 00:05:00              NaN
# 2913951         2  2023-02-28 23:26:02   2023-02-28 23:37:10              NaN
# 2913952         2  2023-02-28 23:24:00   2023-02-28 23:38:00              NaN
# 2913953         2  2023-02-28 23:03:00   2023-02-28 23:10:00              NaN
# 2913954         2  2023-02-28 23:03:03   2023-02-28 23:12:51              NaN
#
# ...

# %%
df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

# %%
std_duration = df['duration'].std()
std_duration
# Out:
# 42.84210176105097

# %%
# df = pd.read_parquet('./data/green_tripdata_2021-01.parquet')


# df = df[(df.duration >= 1) & (df.duration <= 60)]
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)
# df[time_comb] = df[time_comb].astype(str)

# Make sure that all dicts have the same keys (not strictly needed with DictVectorizer but good hygiene)
df_dicts = df[categorical].fillna('missing').to_dict(orient='records')

# Instantiate the DictVectorizer

# %%
with open('lin_reg_2023_01.bin', 'rb') as f_in:
    dv, lr = pickle.load(f_in)

# %%
from scipy.sparse import hstack

X_test = dv.transform(df_dicts)  # This has 514 features
# Step 2: Check shape difference
n_expected_features = lr.n_features_in_  # Should be 515
n_current_features = X_test.shape[1]

# Step 3: If missing features, pad with zero columns
if n_current_features < n_expected_features:
    from scipy.sparse import csr_matrix
    padding = csr_matrix((X_test.shape[0], n_expected_features - n_current_features))
    X_test_fixed = hstack([X_test, padding])
else:
    X_test_fixed = X_test

# %%
y_test_pred = lr.predict(X_test_fixed)

# %%
target = 'duration'
y_test = df[target].values





root_mean_squared_error(y_test_pred, y_test)
# Out:
# 45.380596231461666

# %%
# Fit and transform the data
# fit_transform performs both fitting and transforming in one step
X = dv.transform(df_dicts)

# Get the dimensionality of the matrix (number of columns)
dimensionality = X.shape[1]

# %%
# Step 1: Convert sparse matrix to dense DataFrame with feature names
X_test_full = pd.DataFrame(X.toarray(), columns=dv.feature_names_)

# Step 2: Ensure all training features are present (pad missing ones with 0)
for col in dv.feature_names_:
    if col not in X_test_full.columns:
        X_test_full[col] = 0

# Step 3: Reorder columns to match training feature order
X_test_full = X_test_full[dv.feature_names_]

# Step 4: Convert back to numpy array (or sparse matrix if needed)
X_fixed = X_test_full.values

# %%
dimensionality
# Out:
# 514

# %%
target = 'duration'
y_test = df[target].values



y_test_pred = lr.predict(X)

root_mean_squared_error(y_test_pred, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-4f2574b0bd62> in <cell line: 0>()
#       4
#       5
# ----> 6 y_test_pred = lr.predict(X)
#       7
#       8 root_mean_squared_error(y_test_pred, y_test)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     295             Returns predicted values.
#     296         """
# --> 297         return self._decision_function(X)
#     298
#     299     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     274         check_is_fitted(self)
#     275
# --> 276         X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     277         coef_ = self.coef_
#     278         if coef_.ndim == 1:
#
# ...

# %%
train_df, temp_df = train_test_split(df, test_size=0.3, random_state=42)

# Second split: validation (15%) and test (15%) from the temp set
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Check the size of splits
print(f"Train size: {len(train_df)}")
print(f"Validation size: {len(val_df)}")
print(f"Test size: {len(test_df)}")
# Out:
# Train size: 2382273
# Validation size: 510487
# Test size: 510488

# %%
# train_dicts = train_df[categorical + numerical + time_comb].to_dict(orient='records')
train_dicts = train_df[categorical + numerical ].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = train_df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

root_mean_squared_error(y_train, y_pred)
# Out:
# 7.721765240679192

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()
# Out:
# <ipython-input-34-5fdabbf3bec2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# <ipython-input-34-5fdabbf3bec2>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='actual')

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)

    return df

# %%
import pickle

# %%
with open('lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
test_dicts = test_df[categorical + numerical ].to_dict(orient='records')

with open('lin_reg.bin', 'rb') as f_in:
    dv, lr = pickle.load(f_in)

# Vectorize the test features
X_test = dv.transform(test_dicts)

# Get the target variable for the test set
y_test = test_df[target].values

# Make predictions on the test set
y_pred_test = lr.predict(X_test)

# %%
root_mean_squared_error(y_test, y_pred_test)
# Out:
# 7.720216983965328

# %%
sns.distplot(y_pred_test, label='prediction')
sns.distplot(y_test, label='actual')

plt.legend()
# Out:
# <ipython-input-39-5fdabbf3bec2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# <ipython-input-39-5fdabbf3bec2>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='actual')
# ...
